# %%
# !pip install requests beautifulsoup4
import requests
from bs4 import BeautifulSoup
# タイトルを取得する対象のURL
url = 'https://news.yahoo.co.jp/articles/75e46e37dd09866e7846493a1154e15653a8feb8'
# GETリクエストを送信し、HTMLを取得する
response = requests.get(url)
# HTMLを解析する
soup = BeautifulSoup(response.text, 'html.parser')
# タイトルの要素を取得する
# CSSセレクタを使用して、タイトルを取得する
title_element = soup.select_one('#uamods > div')
# タイトルのテキストを取得する
title_text = title_element.text

# タイトルを表示する
print(title_text)
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.27.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.4.1)
# ウェザーマップ　27日(木)も全国的に厳しい暑さが続き、西日本から北日本にかけて35℃以上の猛暑日になる所が多そうです。内陸では38℃～39℃くらいまで上がる所もあり、危険な暑さになりそうです。また広い範囲で大気の状態が不安定でにわか雨や急な雷雨にも注意が必要です。26日(水)の最高気温　26日(水)も全国的に厳しい暑さとなり、最高気温は東京で37.7℃、名古屋で38.2℃など今年一番の暑さになった所も多くなりました。40℃に迫る勢いで気温の上がった所もありましたが、27日(木)も厳しい暑さが続く見込みです。27日(木)の予想最高気温　27日(木)も西日本から北日本にかけて35℃以上の猛暑日になる所が多いでしょう。内陸では38℃～39℃くらいまで上がる所もある見込みです。危険な暑さになるため、引き続き涼しい場所で無理をしないようにお過ごしください。27日(木)の全国天気と予想気温　また午後は広い範囲で大気の状態が不安定になり、所々でにわか雨や雷雨がある見込みです。雨マークがついていない所がほとんどですが、急な激しい雨や突風、ひょうなどにも注意が必要です。台風5号の進路予想図　台風5号の影響で沖縄の先島諸島では大しけとなっていて、27日(木)も引き続きうねりを伴う高波に警戒が必要です。沖縄本島でも次第に風が強まるため、強風にご注意ください。
# （気象予報士・與猶茉穂）
